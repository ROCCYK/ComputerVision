# %%
from skimage.io import imread
from skimage.color import rgb2gray
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage

# %%
# Scaling the image pixels values within 0-1
img = imread('C:/Users/Downloads/COSC/images/apple-orange.jpg') / 255

# %%
plt.imshow(img)
plt.title('Original')
plt.show()

# %%
# For clustering the image using k-means, we first need to convert it into a 2-dimensional array
image_2D = img.reshape(img.shape[0]*img.shape[1], img.shape[2])

# %%
image_2D.shape
# Out:
# (667000, 3)

# %%
# Use KMeans clustering algorithm from sklearn.cluster to cluster pixels in image
from sklearn.cluster import KMeans

# Tweak the cluster size and see what happens to the Output
kmeans = KMeans(n_clusters=5, random_state=0).fit(image_2D)
clustered = kmeans.cluster_centers_[kmeans.labels_]

# %%
# Reshape back the image from 2D to 3D image
clustered_3D = clustered.reshape(img.shape[0], img.shape[1], img.shape[2])

# %%
clustered_3D.shape
# Out:
# (667, 1000, 3)

# %%
plt.imshow(clustered_3D)
plt.title('Clustered Image')
plt.show()

# %% [markdown]
# There are five clusters in the image
# 01. The Green part of Apples
# 02. The Orange part of Oranges
# 03. The Gray Shadows at bottom of the Apples and oranges
# 04. Bright Yellowish part of Apple's top and right parts
# 05. White Background
